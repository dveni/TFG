# %% [markdown]
# This notebook show how to generate a pandas dataframe from several JSON files with tweets captures using the Stream API.
# Particularly, two dataframes are generated:
# * A dataframe with tweet and user info
# * A dataframe with location info of the tweets

# %% [markdown]
# # Configuration
#
# * Connection with Master notebook is configures
# * DIfferent variables are set

# %%
# check if IS_MASTER exists, this variable will only exist if it's being called by MASTER notebook.
# if it does not exist, set it to False
try: IS_MASTER
except: IS_MASTER = False
# The code below will only run if it's NOT being called from MASTER notebook
if not IS_MASTER:
    # targetFiles = 'HealthyFood'
    # targetFiles = 'UnhealthyFood'
    targetFiles = 'GenericTweets'
    DATA_DIR = './data/temp/' # 
#The code expects a folder (targetFiles) with the next tree structure inside:
# - Name of captured dataset (JSON files)
# |- Year
#  |- Month
#   |- Day
#    |- JSON files
RAW_JSON_DIR = f'./data/JSONFiles/{targetFiles}' #Path to the root folder of JSON files containing tweets
RAW_CSV_DIR = f'./data/CSVFiles/'
PROCESSED_CSV_FILE = f'./{RAW_CSV_DIR}/{targetFiles}-DataFrame.csv'
PROCESSED_LOCATION_CSV_FILE = f'./{RAW_CSV_DIR}/{targetFiles}-LocationsDataframe.csv' # use "small data" here

# %%
#Libraries used in the notebook
import csv
import json
import numpy as np
import pandas as pd
import glob
import os
import ntpath
import pickle
import shutil

# %% [markdown]
# # 1: Transform the json files to csv

# %%
#We get a list with all target JSON files

files = glob.glob(f'{RAW_JSON_DIR}/**/*.json', recursive=True)
files.sort()
filenames = []
for file in files:
    filename=os.path.splitext(file)[0]
    filename = ntpath.basename(filename)
    filenames.append(filename)

filenames
# Out:
# ['2019_11_13_13_36_41-Copy1',
#  '2019_11_13_14_36_42-Copy1',
#  '2019_11_13_15_36_43-Copy1',
#  '2019_11_13_16_36_43-Copy1',
#  '2019_11_13_17_36_43-Copy1',
#  '2019_11_13_18_36_44-Copy1']

# %%
# Convert JSON to CSV files
# It may take some time
i = 0
NEW_FILES = 0
outdir = RAW_CSV_DIR + 'temp/'
if not os.path.exists(outdir):
    os.mkdir(outdir)
failed_files = []                              #JSON files in this list need a ']' at the end due to interrupts during the stream capture

for file in files:
    outname = '{}'.format(filenames[i])+'.csv'
    fullname = os.path.join(outdir, outname)
    i+=1

    if not os.path.exists(fullname):
        print('Creating {}'.format(fullname))
        with open(file, encoding='utf-8-sig') as f_input:
            try:
                df = pd.read_json(f_input)
            except:
                failed_files.append(f_input)
            
        df.to_csv(fullname , index=False)
        NEW_FILES +=1

print('{} new csv files has been created'.format(NEW_FILES))
# Out:
# Creating ./data/CSVFiles/temp/2019_11_13_13_36_41-Copy1.csv
# Creating ./data/CSVFiles/temp/2019_11_13_14_36_42-Copy1.csv
# Creating ./data/CSVFiles/temp/2019_11_13_15_36_43-Copy1.csv
# Creating ./data/CSVFiles/temp/2019_11_13_16_36_43-Copy1.csv
# Creating ./data/CSVFiles/temp/2019_11_13_17_36_43-Copy1.csv
# Creating ./data/CSVFiles/temp/2019_11_13_18_36_44-Copy1.csv
# 6 new csv files has been created

# %%
failed_files
# Out:
# []

# %% [markdown]
# # 2: Create a dataframe

# %%
#files = glob.glob(f'{RAW_CSV_DIR}temp/*.csv')
files = glob.glob(f'{RAW_CSV_DIR}/smallData-DataFrame.csv')
files.sort()
files
# Out:
# ['./data/CSVFiles//smallData-DataFrame.csv']

# %%
# Join all csv files in one dataframe in case there are new files
#TODO:It could have less computational cost if we only join new csv files

if NEW_FILES != 0:

    df = pd.DataFrame()
    print(df.shape)

    li = []

    for filename in files:
        df_temp = pd.read_csv(filename, index_col=None, header=0, lineterminator='\n')
        df_temp = df_temp[['coordinates','created_at','geo','id','id_str','lang','place',
                           'text','user', 'extended_tweet', 'truncated', 'extended_entities']]
        li.append(df_temp)

    df = pd.concat(li, axis=0, ignore_index=True)
    print(df.shape)

    #shutil.rmtree(outdir)
    
    #Filter RTs

    df = df[df['text'].str.contains("RT @") == False]
    df = df.reset_index()
    
    print(df.shape)
# Out:
# (0, 0)
# (13525, 12)
# (13525, 13)

# %%
#Get full text from extended tweet
def getFullText(truncated, extended_tweet):
    if truncated:
        a = extended_tweet.replace("'", '"')
        try:
            b = json.loads(a)
            res = b['full_text']
        except:
            res = None
        return res

# %%
if NEW_FILES != 0:
    df['full_text'] = df.apply(lambda x: getFullText(x['truncated'], x['extended_tweet']) , axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13525 entries, 0 to 13524
# Data columns (total 14 columns):
# index                13525 non-null int64
# coordinates          50 non-null object
# created_at           13525 non-null object
# geo                  50 non-null object
# id                   13525 non-null float64
# id_str               13525 non-null float64
# lang                 13525 non-null object
# place                525 non-null object
# text                 13525 non-null object
# user                 13525 non-null object
# extended_tweet       3312 non-null object
# truncated            13525 non-null float64
# extended_entities    653 non-null object
# full_text            2780 non-null object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 1.4+ MB

# %%
def getText2Proc(fullText, text):
    if fullText is not None:
        return (fullText)
    else:
        return (text)

# %%
df['text2Proc'] = df.apply(lambda x: getText2Proc(x['full_text'], x['text']) , axis=1)
df.head()
# Out:
#    index coordinates               created_at  geo            id  \
# 0      0         NaN  2019-11-07 15:51:39.000  NaN  1.192470e+18
# 1      1         NaN  2019-11-07 15:52:52.000  NaN  1.192470e+18
# 2      2         NaN  2019-11-07 15:53:49.000  NaN  1.192470e+18
# 3      3         NaN  2019-11-07 15:54:03.000  NaN  1.192470e+18
# 4      4         NaN  2019-11-07 15:55:01.000  NaN  1.192471e+18
#
#          id_str lang place                                               text  \
# 0  1.192470e+18   es   NaN  Nunca voy a entender por qué #Bienvenidos13 si...
# 1  1.192470e+18   es   NaN  @MalenaAubone NooOOoOOo man voy a comprar hela...
# 2  1.192470e+18   es   NaN  Estamos en una parri con mi viejo, al costado ...
# 3  1.192470e+18   es   NaN                         No nos extinguimos de pedo
# 4  1.192471e+18   es   NaN  Desde las 11am. Que pienso en el helado que es...
#
#                                                 user  \
# 0  {'id': 284654792, 'id_str': '284654792', 'name...
# 1  {'id': 3029655005, 'id_str': '3029655005', 'na...
# 2  {'id': 602970512, 'id_str': '602970512', 'name...
# 3  {'id': 1726824211, 'id_str': '1726824211', 'na...
# 4  {'id': 185476629, 'id_str': '185476629', 'name...
#
#                                       extended_tweet  truncated  \
# 0  {'full_text': 'Nunca voy a entender por qué #B...        1.0
# 1                                                NaN        0.0
# 2  {'full_text': 'Estamos en una parri con mi vie...        1.0
# 3                                                NaN        0.0
# 4                                                NaN        0.0
#
#   extended_entities                                          full_text  \
# 0               NaN  Nunca voy a entender por qué #Bienvenidos13 si...
# 1               NaN                                               None
# 2               NaN  Estamos en una parri con mi viejo, al costado ...
# 3               NaN                                               None
# 4               NaN                                               None
#
#                                            text2Proc
# 0  Nunca voy a entender por qué #Bienvenidos13 si...
# 1  @MalenaAubone NooOOoOOo man voy a comprar hela...
# 2  Estamos en una parri con mi viejo, al costado ...
# 3                         No nos extinguimos de pedo
# 4  Desde las 11am. Que pienso en el helado que es...

# %%
outdir = RAW_CSV_DIR
if not os.path.exists(outdir):
    os.mkdir(outdir)
df.to_csv(PROCESSED_CSV_FILE, index=False)

# %% [markdown]
# # 3: Get tweet location

# %%
# Get user location
users = df.user.values
locations = []

if NEW_FILES != 0:
    for user in users:
        keyword = "'location':"
        before_keyword, keyword, after_keyword = user.partition(keyword)
        my_string = after_keyword
        keyword = "'url':"
        before_keyword, keyword, after_keyword = my_string.partition(keyword)
        user_location = before_keyword.replace(',','').replace("\'",'').replace('\"','').strip()
        locations.append(user_location)
    df = df.assign(user_location = locations)
    df = df.replace('None', np.NaN)

# %%
# Get tweet location

if NEW_FILES != 0:
    place = df.place

    longitude = []
    latitude = []
    country = []
    city = []
    n=0
    for i in place.values:
        a = ''
        if not isinstance(i, float):
            a = i.replace("'", '"')

        try:
            b = json.loads(a)
            n = n + 1
            longitude.append(b['bounding_box']['coordinates'][0][0][0])
            latitude.append(b['bounding_box']['coordinates'][0][0][1])
            country.append(b['country'])
            city.append(b['name'])
        except ValueError:
            longitude.append(np.NaN)
            latitude.append(np.NaN)
            country.append(np.NaN)
            city.append(np.NaN)
            continue
    df['Country'] = country
    df['City'] = city
    df['Longitude'] = longitude
    df['Latitude'] = latitude
    df['Coordinates'] = list(zip(df.Longitude, df.Latitude))

    df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14703 entries, 0 to 14702
# Data columns (total 21 columns):
# index                14703 non-null int64
# coordinates          75 non-null object
# created_at           14703 non-null object
# geo                  75 non-null object
# id                   14703 non-null int64
# id_str               14703 non-null int64
# lang                 14703 non-null object
# place                600 non-null object
# text                 14703 non-null object
# user                 14703 non-null object
# extended_tweet       5959 non-null object
# truncated            14703 non-null bool
# extended_entities    595 non-null object
# full_text            4801 non-null object
# text2Proc            14703 non-null object
# user_location        10331 non-null object
# Country              598 non-null object
# City                 598 non-null object
# Longitude            598 non-null float64
# Latitude             598 non-null float64
# Coordinates          14703 non-null object
# dtypes: bool(1), float64(2), int64(3), object(15)
# memory usage: 2.3+ MB

# %%
df_original = df

# %% [markdown]
# ### Create a dataframe with locations for statistical analysis

# %%
df = df[['Country', 'City', 'Longitude', 'Latitude']][df['Country'].notna()]
df['Coordinates'] = list(zip(df.Longitude, df.Latitude))
df
# Out:
#          Country                             City   Longitude   Latitude  \
# 30        España                        Palomeque   -4.017543  40.095033
# 38        España                         Valencia   -0.432545  39.278381
# 49        España                           Oviedo   -6.020100  43.278867
# 68          Peru                            Lince  -77.045913 -12.093449
# 80     Argentina                    Villa Soldati  -58.502543 -34.705421
# 117       México                        Guadalupe -100.274823  25.621688
# 148       España                    Lloret de Mar    2.775933  41.686311
# 157    Venezuela                           Mérida  -71.195747   8.566088
# 178    Argentina  Ciudad Autónoma de Buenos Aires  -58.531792 -34.674453
# 214         Peru                        La Molina  -76.972519 -12.124810
# 220    Tailandia                          ตลาดยอด  100.494335  13.757552
# 232       España                           Madrid   -3.889005  40.312071
# 242         Peru                       San isidro  -77.062760 -12.113561
# 290       España                          Sevilla   -6.028430  37.313613
# 291       España       Las Palmas de Gran Canaria  -15.525504  28.024813
# 293       México              Ecatepec de Morelos  -99.118665  19.484399
# 299    Argentina                      Casa Tomada  -65.309366 -24.186297
# 373     Colombia                           Caldas  -75.694574   5.969350
# 374       México                   Álvaro Obregón  -99.324375  19.232228
# 387         Peru                      Jesús Maria  -77.059460 -12.095034
# 408    Argentina                      Resistencia  -59.059307 -27.505327
# 445       México                     Huixquilucan  -99.404165  19.305971
# 451         Peru                            Lince  -77.045913 -12.093449
# 531       México                     Huixquilucan  -99.404165  19.305971
# 536    Argentina                     Buenos Aires  -63.393860 -41.035009
# 578       Brasil                          Uberaba  -48.355618 -20.125352
# 594      Rumanía                         Bucarest   25.963699  44.349420
# 686       España                         Albacete   -2.181299  38.672083
# 701         Peru                             Lima  -77.088074 -12.080577
# 716     Colombia                     Bogotá, D.C.  -74.483289   3.717432
# ...          ...                              ...         ...        ...
# 13905     España                            Galar   -1.724087  42.697814
# 13916  Argentina                 Belén de Escobar  -58.863099 -34.456428
# 13920     Canada                          Toronto  -79.639319  43.403221
# 13954       Peru                             Lima  -77.088074 -12.080577
# 13958     España                    Pineda de Mar    2.627270  41.615030
# 13978      Spain               Boadilla del Monte   -3.952603  40.377576
# 14021  Argentina                          Formosa  -58.238548 -26.209999
# 14138   Colombia                     Bogotá, D.C.  -74.483289   3.717432
# 14147   Paraguay                         Neembucu  -58.668313 -27.421413
# 14175      Spain       Las Palmas de Gran Canaria  -15.525504  28.024813
# 14180  Argentina  Ciudad Autónoma de Buenos Aires  -58.531792 -34.674453
# 14191     México                       Cuauhtémoc  -99.184350  19.399835
# 14213     Panamá                           Panamá  -83.051445   7.203860
# 14214  Argentina  Ciudad Autónoma de Buenos Aires  -58.531792 -34.674453
# 14246  Venezuela                    Nueva Esparta  -66.956004  10.736010
# 14252       Peru                 San Juan de Iris  -76.553073 -11.778478
# 14287  Argentina                            Unión  -62.706463 -32.642557
# 14313     España                           Málaga   -4.587928  36.635585
# 14423     México                     Isla Mujeres  -87.395993  21.200226
# 14450     España                          Ourense   -8.003734  42.288179
# 14491     España                         Valencia   -0.432545  39.278381
# 14502      Chile                       Valparaíso  -80.114855 -33.213554
# 14504     México                       Hermosillo -112.615459  28.228442
# 14570     España                           Madrid   -3.889005  40.312071
# 14608     España                         Zaragoza   -1.174093  41.451835
# 14614  Argentina                General Rodríguez  -59.023527 -34.651782
# 14615  Argentina                General Rodríguez  -59.023527 -34.651782
# 14652     España                          Sevilla   -6.028430  37.313613
# 14682    Ecuador                        Guayaquil  -80.467605  -3.063716
# 14702  Argentina                    Puerto Madryn  -65.072389 -42.790148
#
#                              Coordinates
# 30                (-4.017543, 40.095033)
# 38     (-0.43254499999999996, 39.278381)
# 49                  (-6.0201, 43.278867)
# 68              (-77.045913, -12.093449)
# 80              (-58.502543, -34.705421)
# 117             (-100.274823, 25.621688)
# 148                (2.775933, 41.686311)
# 157               (-71.195747, 8.566088)
# 178             (-58.531792, -34.674453)
# 214              (-76.972519, -12.12481)
# 220              (100.494335, 13.757552)
# 232               (-3.889005, 40.312071)
# 242              (-77.06276, -12.113561)
# 290                (-6.02843, 37.313613)
# 291              (-15.525504, 28.024813)
# 293              (-99.118665, 19.484399)
# 299             (-65.309366, -24.186297)
# 373                (-75.694574, 5.96935)
# 374              (-99.324375, 19.232228)
# 387              (-77.05946, -12.095034)
# 408             (-59.059307, -27.505327)
# 445              (-99.404165, 19.305971)
# 451             (-77.045913, -12.093449)
# 531              (-99.404165, 19.305971)
# 536              (-63.39386, -41.035009)
# 578             (-48.355618, -20.125352)
# 594                (25.963699, 44.34942)
# 686               (-2.181299, 38.672083)
# 701             (-77.088074, -12.080577)
# 716               (-74.483289, 3.717432)
# ...                                  ...
# 13905             (-1.724087, 42.697814)
# 13916           (-58.863099, -34.456428)
# 13920            (-79.639319, 43.403221)
# 13954           (-77.088074, -12.080577)
# 13958                (2.62727, 41.61503)
# 13978             (-3.952603, 40.377576)
# 14021           (-58.238548, -26.209999)
# 14138             (-74.483289, 3.717432)
# 14147           (-58.668313, -27.421413)
# 14175            (-15.525504, 28.024813)
# 14180           (-58.531792, -34.674453)
# 14191             (-99.18435, 19.399835)
# 14213              (-83.051445, 7.20386)
# 14214           (-58.531792, -34.674453)
# 14246             (-66.956004, 10.73601)
# 14252           (-76.553073, -11.778478)
# 14287           (-62.706463, -32.642557)
# 14313             (-4.587928, 36.635585)
# 14423            (-87.395993, 21.200226)
# 14450             (-8.003734, 42.288179)
# 14491  (-0.43254499999999996, 39.278381)
# 14502           (-80.114855, -33.213554)
# 14504           (-112.615459, 28.228442)
# 14570             (-3.889005, 40.312071)
# 14608             (-1.174093, 41.451835)
# 14614           (-59.023527, -34.651782)
# 14615           (-59.023527, -34.651782)
# 14652              (-6.02843, 37.313613)
# 14682            (-80.467605, -3.063716)
# 14702           (-65.072389, -42.790148)
#
# [598 rows x 5 columns]

# %%
df.to_csv(PROCESSED_LOCATION_CSV_FILE, index=False)

# %%
#get tweets from Spain
df = df_original
df.loc[df['Country'] == "España", 'Country'] = 'Spain'
df.loc[df['Country'] == "Espanya", 'Country'] = 'Spain'
df_spain = df = df[df.Country == 'Spain']
df_spain = df_spain.reset_index()
df_spain
# Out:
#      level_0  index                                        coordinates  \
# 0         30     87                                                NaN
# 1         38    105                                                NaN
# 2         49    136                                                NaN
# 3        148    506                                                NaN
# 4        232    782  {'type': 'Point', 'coordinates': [-3.69051871,...
# 5        290    953                                                NaN
# 6        291    958                                                NaN
# 7        686   2256                                                NaN
# 8        944   3006                                                NaN
# 9       1250   3896  {'type': 'Point', 'coordinates': [-3.68333, 40...
# 10      1338   4201                                                NaN
# 11      1415   4431                                                NaN
# 12      1472   4601  {'type': 'Point', 'coordinates': [-0.8827, 41....
# 13      1494   4666                                                NaN
# 14      1512   4706  {'type': 'Point', 'coordinates': [-1.85887, 38...
# 15      1540   4794                                                NaN
# 16      1588   4941                                                NaN
# 17      1696   5314  {'type': 'Point', 'coordinates': [-0.8827, 41....
# 18      1837   5733                                                NaN
# 19      1850   5776                                                NaN
# 20      2038   6379                                                NaN
# 21      2076   6506                                                NaN
# 22      2308   7305                                                NaN
# 23      2318   7334                                                NaN
# 24      2376   7524                                                NaN
# 25      2435   7693                                                NaN
# 26      2491   7869                                                NaN
# 27      2634   8316                                                NaN
# 28      2678   8434                                                NaN
# 29      2808   8822                                                NaN
# ..       ...    ...                                                ...
# 84     11167  33555  {'type': 'Point', 'coordinates': [-2.56153894,...
# 85     11343  34148                                                NaN
# 86     11621  34897                                                NaN
# 87     12092  36228                                                NaN
# 88     12143  36357                                                NaN
# 89     12299  36825                                                NaN
# 90     12395  37130                                                NaN
# 91     12509  37507                                                NaN
# 92     12688  38039                                                NaN
# 93     12711  38096                                                NaN
# 94     12979  38959                                                NaN
# 95     13016  39065                                                NaN
# 96     13017  39072                                                NaN
# 97     13039  39123                                                NaN
# 98     13058  39182  {'type': 'Point', 'coordinates': [2.166869, 41...
# 99     13169  39501                                                NaN
# 100    13280  39791                                                NaN
# 101    13353  40015                                                NaN
# 102    13837  41343                                                NaN
# 103    13875  41431  {'type': 'Point', 'coordinates': [-3.68623092,...
# 104    13905  41498                                                NaN
# 105    13958  41646                                                NaN
# 106    13978  41702                                                NaN
# 107    14175  42224                                                NaN
# 108    14313  42588  {'type': 'Point', 'coordinates': [-4.46018529,...
# 109    14450  42941                                                NaN
# 110    14491  43058                                                NaN
# 111    14570  43299                                                NaN
# 112    14608  43408                                                NaN
# 113    14652  43564                                                NaN
#
#                   created_at  \
# 0    2019-11-13 13:37:28.000
# 1    2019-11-13 13:37:42.000
# 2    2019-11-13 13:37:59.000
# 3    2019-11-13 13:41:35.000
# 4    2019-11-13 13:44:14.000
# 5    2019-11-13 13:45:53.000
# 6    2019-11-13 13:45:57.000
# 7    2019-11-13 13:57:50.000
# 8    2019-11-13 14:04:50.000
# 9    2019-11-13 14:13:06.000
# 10   2019-11-13 14:15:52.000
# 11   2019-11-13 14:18:02.000
# 12   2019-11-13 14:19:29.000
# 13   2019-11-13 14:20:02.000
# 14   2019-11-13 14:20:24.000
# 15   2019-11-13 14:21:13.000
# 16   2019-11-13 14:22:36.000
# 17   2019-11-13 14:25:43.000
# 18   2019-11-13 14:29:31.000
# 19   2019-11-13 14:29:51.000
# 20   2019-11-13 14:35:13.000
# 21   2019-11-13 14:36:20.000
# 22   2019-11-13 14:43:24.000
# 23   2019-11-13 14:43:35.000
# 24   2019-11-13 14:45:15.000
# 25   2019-11-13 14:46:33.000
# 26   2019-11-13 14:48:16.000
# 27   2019-11-13 14:52:02.000
# 28   2019-11-13 14:53:02.000
# 29   2019-11-13 14:56:30.000
# ..                       ...
# 84   2019-11-13 18:07:38.000
# 85   2019-11-13 18:12:29.000
# 86   2019-11-13 18:18:50.000
# 87   2019-11-13 18:30:26.000
# 88   2019-11-13 18:31:34.000
# 89   2019-11-13 18:35:46.000
# 90   2019-11-13 18:38:15.000
# 91   2019-11-13 18:41:31.000
# 92   2019-11-13 18:46:16.000
# 93   2019-11-13 18:46:47.000
# 94   2019-11-13 18:54:13.000
# 95   2019-11-13 18:55:00.000
# 96   2019-11-13 18:55:02.000
# 97   2019-11-13 18:55:20.000
# 98   2019-11-13 18:55:48.000
# 99   2019-11-13 18:58:32.000
# 100  2019-11-13 19:01:01.000
# 101  2019-11-13 19:03:03.000
# 102  2019-11-13 19:14:46.000
# 103  2019-11-13 19:15:40.000
# 104  2019-11-13 19:16:13.000
# 105  2019-11-13 19:17:30.000
# 106  2019-11-13 19:18:02.000
# 107  2019-11-13 19:22:41.000
# 108  2019-11-13 19:25:56.000
# 109  2019-11-13 19:29:28.000
# 110  2019-11-13 19:30:30.000
# 111  2019-11-13 19:32:36.000
# 112  2019-11-13 19:33:41.000
# 113  2019-11-13 19:35:09.000
#
#                                                    geo                   id  \
# 0                                                  NaN  1194610231965364224
# 1                                                  NaN  1194610288701714433
# 2                                                  NaN  1194610359233122306
# 3                                                  NaN  1194611265802518528
# 4    {'type': 'Point', 'coordinates': [40.42790112,...  1194611934433165312
# 5                                                  NaN  1194612350529216512
# 6                                                  NaN  1194612367033880577
# 7                                                  NaN  1194615358046507008
# 8                                                  NaN  1194617117833863168
# 9    {'type': 'Point', 'coordinates': [40.4, -3.683...  1194619197227196418
# 10                                                 NaN  1194619892810559488
# 11                                                 NaN  1194620441752752128
# 12   {'type': 'Point', 'coordinates': [41.6503, -0....  1194620805570875394
# 13                                                 NaN  1194620944788017152
# 14   {'type': 'Point', 'coordinates': [38.99583, -1...  1194621036622307329
# 15                                                 NaN  1194621242961096705
# 16                                                 NaN  1194621588601073668
# 17   {'type': 'Point', 'coordinates': [41.6503, -0....  1194622373154213888
# 18                                                 NaN  1194623329220595712
# 19                                                 NaN  1194623415161905152
# 20                                                 NaN  1194624765845102593
# 21                                                 NaN  1194625044200050688
# 22                                                 NaN  1194626823214288896
# 23                                                 NaN  1194626870345469954
# 24                                                 NaN  1194627289608122368
# 25                                                 NaN  1194627614922567683
# 26                                                 NaN  1194628047837655044
# 27                                                 NaN  1194628996161343495
# 28                                                 NaN  1194629246225768449
# 29                                                 NaN  1194630120037703681
# ..                                                 ...                  ...
# 84   {'type': 'Point', 'coordinates': [42.46699167,...  1194678221624598528
# 85                                                 NaN  1194679442066546688
# 86                                                 NaN  1194681038259314689
# 87                                                 NaN  1194683958891569152
# 88                                                 NaN  1194684245647732737
# 89                                                 NaN  1194685298510352385
# 90                                                 NaN  1194685924531150848
# 91                                                 NaN  1194686746556014595
# 92                                                 NaN  1194687943958573061
# 93                                                 NaN  1194688074627899392
# 94                                                 NaN  1194689942691209217
# 95                                                 NaN  1194690138846253057
# 96                                                 NaN  1194690149881397250
# 97                                                 NaN  1194690224095420418
# 98   {'type': 'Point', 'coordinates': [41.390994, 2...  1194690340617433089
# 99                                                 NaN  1194691029565419520
# 100                                                NaN  1194691654428569601
# 101                                                NaN  1194692166641168384
# 102                                                NaN  1194695117359087616
# 103  {'type': 'Point', 'coordinates': [40.4363166, ...  1194695343495143424
# 104                                                NaN  1194695480464355329
# 105                                                NaN  1194695801664155655
# 106                                                NaN  1194695935923806209
# 107                                                NaN  1194697109502648320
# 108  {'type': 'Point', 'coordinates': [36.68759667,...  1194697924569128961
# 109                                                NaN  1194698815368056832
# 110                                                NaN  1194699075410628608
# 111                                                NaN  1194699603867766788
# 112                                                NaN  1194699873813180416
# 113                                                NaN  1194700244795170817
#
#                   id_str lang  \
# 0    1194610231965364224   es
# 1    1194610288701714432   es
# 2    1194610359233122304   es
# 3    1194611265802518528   es
# 4    1194611934433165312   es
# 5    1194612350529216512   es
# 6    1194612367033880576   es
# 7    1194615358046507008   es
# 8    1194617117833863168   es
# 9    1194619197227196416   es
# 10   1194619892810559488   es
# 11   1194620441752752128   es
# 12   1194620805570875392   es
# 13   1194620944788017152   es
# 14   1194621036622307328   es
# 15   1194621242961096704   es
# 16   1194621588601073664   es
# 17   1194622373154213888   es
# 18   1194623329220595712   es
# 19   1194623415161905152   es
# 20   1194624765845102592   es
# 21   1194625044200050688   es
# 22   1194626823214288896   es
# 23   1194626870345469952   es
# 24   1194627289608122368   es
# 25   1194627614922567680   es
# 26   1194628047837655040   es
# 27   1194628996161343488   es
# 28   1194629246225768448   es
# 29   1194630120037703680   es
# ..                   ...  ...
# 84   1194678221624598528   es
# 85   1194679442066546688   es
# 86   1194681038259314688   es
# 87   1194683958891569152   es
# 88   1194684245647732736   es
# 89   1194685298510352384   es
# 90   1194685924531150848   es
# 91   1194686746556014592   es
# 92   1194687943958573056   es
# 93   1194688074627899392   es
# 94   1194689942691209216   es
# 95   1194690138846253056   es
# 96   1194690149881397248   es
# 97   1194690224095420416   es
# 98   1194690340617433088   es
# 99   1194691029565419520   es
# 100  1194691654428569600   es
# 101  1194692166641168384   es
# 102  1194695117359087616   es
# 103  1194695343495143424   es
# 104  1194695480464355328   es
# 105  1194695801664155648   es
# 106  1194695935923806208   es
# 107  1194697109502648320   es
# 108  1194697924569128960   es
# 109  1194698815368056832   es
# 110  1194699075410628608   es
# 111  1194699603867766784   es
# 112  1194699873813180416   es
# 113  1194700244795170816   es
#
#                                                  place  \
# 0    {'id': '369ff584feaf6201', 'url': 'https://api...
# 1    {'id': '071a52d3a927a1b8', 'url': 'https://api...
# 2    {'id': 'd1272bba8714df3d', 'url': 'https://api...
# 3    {'id': '16d7e4bdce732b26', 'url': 'https://api...
# 4    {'id': '206c436ce43a43a3', 'url': 'https://api...
# 5    {'id': '8c86b8b4cb716103', 'url': 'https://api...
# 6    {'id': '00ab08eef1b62e92', 'url': 'https://api...
# 7    {'id': '56933d34eb0f964a', 'url': 'https://api...
# 8    {'id': 'f4250a690d3b8039', 'url': 'https://api...
# 9    {'id': '206c436ce43a43a3', 'url': 'https://api...
# 10   {'id': '18760d8c2f8ec22e', 'url': 'https://api...
# 11   {'id': '4046ac3a05c54146', 'url': 'https://api...
# 12   {'id': '3afc29d1fe76301f', 'url': 'https://api...
# 13   {'id': 'c52827ebd9bfe563', 'url': 'https://api...
# 14   {'id': '56933d34eb0f964a', 'url': 'https://api...
# 15   {'id': '387b00909c2e7031', 'url': 'https://api...
# 16   {'id': '206c436ce43a43a3', 'url': 'https://api...
# 17   {'id': '3afc29d1fe76301f', 'url': 'https://api...
# 18   {'id': '206c436ce43a43a3', 'url': 'https://api...
# 19   {'id': '387b00909c2e7031', 'url': 'https://api...
# 20   {'id': '1a27537478dd8e38', 'url': 'https://api...
# 21   {'id': '206c436ce43a43a3', 'url': 'https://api...
# 22   {'id': '206c436ce43a43a3', 'url': 'https://api...
# 23   {'id': 'ea520f3528c9b3e4', 'url': 'https://api...
# 24   {'id': '394ff7ddd49995ae', 'url': 'https://api...
# 25   {'id': '507a015cba6ef518', 'url': 'https://api...
# 26   {'id': '2afe3164f39d1b83', 'url': 'https://api...
# 27   {'id': 'abfd00c5f14e271e', 'url': 'https://api...
# 28   {'id': '206c436ce43a43a3', 'url': 'https://api...
# 29   {'id': '1a27537478dd8e38', 'url': 'https://api...
# ..                                                 ...
# 84   {'id': 'cb27712b983d86de', 'url': 'https://api...
# 85   {'id': 'cce502c993ca9dd2', 'url': 'https://api...
# 86   {'id': '689e141371932683', 'url': 'https://api...
# 87   {'id': '507a015cba6ef518', 'url': 'https://api...
# 88   {'id': '8c86b8b4cb716103', 'url': 'https://api...
# 89   {'id': '1a27537478dd8e38', 'url': 'https://api...
# 90   {'id': '3afc29d1fe76301f', 'url': 'https://api...
# 91   {'id': '08eb5d76dc74e0e9', 'url': 'https://api...
# 92   {'id': 'b56aaebbd105a09e', 'url': 'https://api...
# 93   {'id': 'b56aaebbd105a09e', 'url': 'https://api...
# 94   {'id': '0df6ac4d361d4e0e', 'url': 'https://api...
# 95   {'id': '0df6ac4d361d4e0e', 'url': 'https://api...
# 96   {'id': '0df6ac4d361d4e0e', 'url': 'https://api...
# 97   {'id': '6c1be133511970bc', 'url': 'https://api...
# 98   {'id': '1a27537478dd8e38', 'url': 'https://api...
# 99   {'id': '206c436ce43a43a3', 'url': 'https://api...
# 100  {'id': 'c6b7997762da90a9', 'url': 'https://api...
# 101  {'id': '0df6ac4d361d4e0e', 'url': 'https://api...
# 102  {'id': '71d49086a15d032e', 'url': 'https://api...
# 103  {'id': '206c436ce43a43a3', 'url': 'https://api...
# 104  {'id': '9b260d25c717f3d9', 'url': 'https://api...
# 105  {'id': '0c57c49e4d495e37', 'url': 'https://api...
# 106  {'id': 'e564ddfcdf4b36fd', 'url': 'https://api...
# 107  {'id': '00ab08eef1b62e92', 'url': 'https://api...
# 108  {'id': '507a015cba6ef518', 'url': 'https://api...
# 109  {'id': 'd9ebaeaac39060be', 'url': 'https://api...
# 110  {'id': '071a52d3a927a1b8', 'url': 'https://api...
# 111  {'id': '206c436ce43a43a3', 'url': 'https://api...
# 112  {'id': '3afc29d1fe76301f', 'url': 'https://api...
# 113  {'id': '8c86b8b4cb716103', 'url': 'https://api...
#
#                                                   text  \
# 0    La veleta naranja se rompió de la tanto giro.\...
# 1    Toma Geroma! Pastillas de goma! Dabuten tronco...
# 2    @nancyacostatfe @Hibai_ @MabelFigueruelo De fr...
# 3    Parece que mermelada se cree el único ser cult...
# 4    Edamame en bartomate \n.\n.\n.\n#edamame #bart...
# 5    información inutil sobre mi:\n\naltura: 1'73\n...
# 6    Hoy está el día para un buen plato de lentejas...
# 7    Este sabroso crumble de calabaza y avellanas e...
# 8    informacion super inutil de mi:\n\naltura: 1,5...
# 9    ¡¡Que hambre!! ¿Y tú  que comes hoy?? Yo unas ...
# 10   Ahora sí se perdió el norte. Sodoma y gomorra ...
# 11   @yatedigoyoque @KIud0 Puedes recurrir al catal...
# 12   [💥PANCAKES CINNAMON ROLL💥 ]\n.\n.\n⬇️INGREDIEN...
# 13   @EstefaniaJoaq Yo no lo creo, más bien "esto e...
# 14   ⠀⠀⠀⠀⠀⠀⠀⠀⠀\n🇪🇸 Comenzamos las comidas de la Aso...
# 15   @yxngmozo @holiest_jambo el d rooibos y frambu...
# 16   @la_flawerova Yo hoy he comido judías verdes, ...
# 17   [💥PANCAKES CACAO💥 ]\n.\n.\n⬇️INGREDIENTES⬇️\n➖...
# 18   Peludito de 2 escasos años q está perdiendo vi...
# 19   en la aso d bcn a la q iba tooooooooooodoooooo...
# 20   @GaliciaED_ @RubenRguezVquez Esto es la pera. ...
# 21   El setter necesitado de adopción está en la ve...
# 22   Retrasar el parto para que el médico vuelva de...
# 23   Está en una veterinaria de Ópera, de la médico...
# 24                      "Este sí es un refrán gallego"
# 25   estamos de acuerdo en que la kas de naranja le...
# 26   @rosadiezglez Me he vuelto malo, ahora porque ...
# 27   📢Aviso 🔶NARANJA por #FMA #Nevadas ❄️🌨️❄️ en #C...
# 28   @FtimaCantalapi1 Me encanta el jugo de frutas,...
# 29   Información inútil sobre mi:\n\nAltura: 1,57\n...
# ..                                                 ...
# 84   ➡️➡️📷 Maravillosos los platos de cuchara en @a...
# 85   @rosadiezglez Tienes alzheimer. Tomate la medi...
# 86   ⚠️AVISOS ROJOS⚠️ naranja y amarillo para toda ...
# 87   informacion super inútil de mí:\n\naltura: 1'7...
# 88   @FAquae Melón de agua \nSandía\nTú tía \nSu ma...
# 89   'A José María hoy le han regalado\nUn coche pe...
# 90   Información súper importante sobre mí:\n\nAltu...
# 91   @oierazkarraga @clacunza La ha votado un señor...
# 92                       @jroto_ Comerte unas lentejas
# 93               La gente a la q le gusta el aquarius?
# 94                       fruta https://t.co/RPPLyt2mSP
# 95                        @chupacaca69 SOLO DIJE FRUTA
# 96   @TitotatinTT Pimiento rojo y pimiento verde\nT...
# 97   A continuación, dando por hecho que esa fruta ...
# 98   MANGO #intimatedinner Paseo de Gracia, 36 - Ba...
# 99   @Pol588 @NebraskaGuy212 Te gusta el pimiento? ...
# 100  @VanesaFeGa Mientras Twitter no escriba las le...
# 101  @TitotatinTT Échale un poquito de nada que es ...
# 102  Jamoncitos de pollo con tomate, la receta que ...
# 103  Comprobado: lo tradicional y sencillo es mucha...
# 104  @jrlaguardia Si me las quito yo veo una berenj...
# 105  @PuriRV Datos tontos sobre mí:\n\nAltura: 1'60...
# 106  información inutil sobre mi:\n\naltura: 1'59\n...
# 107                             el mango por la sartén
# 108  ADOPTADA LLUVIA...nuestra princesa de ocho añi...
# 109  @pburelli @Reportero24 Ese pollo pronto será c...
# 110  Exijo arco iris con luces en todos los conciertos
# 111  “La poesía,en fin, esa energía secreta de la v...
# 112  Lo dice alguien que su contribución a la socie...
# 113  información inutil sobre mi:\n\naltura: 1'74\n...
#
#                    ...                 truncated  \
# 0                  ...                     False
# 1                  ...                     False
# 2                  ...                     False
# 3                  ...                     False
# 4                  ...                      True
# 5                  ...                      True
# 6                  ...                     False
# 7                  ...                      True
# 8                  ...                      True
# 9                  ...                      True
# 10                 ...                     False
# 11                 ...                      True
# 12                 ...                      True
# 13                 ...                     False
# 14                 ...                      True
# 15                 ...                     False
# 16                 ...                     False
# 17                 ...                      True
# 18                 ...                     False
# 19                 ...                      True
# 20                 ...                      True
# 21                 ...                      True
# 22                 ...                     False
# 23                 ...                     False
# 24                 ...                     False
# 25                 ...                     False
# 26                 ...                      True
# 27                 ...                      True
# 28                 ...                     False
# 29                 ...                      True
# ..                 ...                       ...
# 84                 ...                      True
# 85                 ...                     False
# 86                 ...                      True
# 87                 ...                      True
# 88                 ...                      True
# 89                 ...                      True
# 90                 ...                      True
# 91                 ...                     False
# 92                 ...                     False
# 93                 ...                     False
# 94                 ...                     False
# 95                 ...                     False
# 96                 ...                     False
# 97                 ...                      True
# 98                 ...                      True
# 99                 ...                     False
# 100                ...                      True
# 101                ...                     False
# 102                ...                     False
# 103                ...                      True
# 104                ...                     False
# 105                ...                      True
# 106                ...                      True
# 107                ...                     False
# 108                ...                      True
# 109                ...                      True
# 110                ...                     False
# 111                ...                      True
# 112                ...                      True
# 113                ...                      True
#
#                                      extended_entities  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18   {'media': [{'id': 1194623305468104704, 'id_str...
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 84                                                 NaN
# 85                                                 NaN
# 86                                                 NaN
# 87                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 94   {'media': [{'id': 1194689936139718661, 'id_str...
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99   {'media': [{'id': 1194691021571002374, 'id_str...
# 100                                                NaN
# 101                                                NaN
# 102  {'media': [{'id': 1194695111118077952, 'id_str...
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
#
#                                              full_text  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4    Edamame en bartomate \n.\n.\n.\n#edamame #bart...
# 5                                                 None
# 6                                                 None
# 7    Este sabroso crumble de calabaza y avellanas e...
# 8    informacion super inutil de mi:\n\naltura: 1,5...
# 9    ¡¡Que hambre!! ¿Y tú  que comes hoy?? Yo unas ...
# 10                                                None
# 11   @yatedigoyoque @KIud0 Puedes recurrir al catal...
# 12   [💥PANCAKES CINNAMON ROLL💥 ]\n.\n.\n⬇️INGREDIEN...
# 13                                                None
# 14   ⠀⠀⠀⠀⠀⠀⠀⠀⠀\n🇪🇸 Comenzamos las comidas de la Aso...
# 15                                                None
# 16                                                None
# 17   [💥PANCAKES CACAO💥 ]\n.\n.\n⬇️INGREDIENTES⬇️\n➖...
# 18                                                None
# 19   en la aso d bcn a la q iba tooooooooooodoooooo...
# 20                                                None
# 21   El setter necesitado de adopción está en la ve...
# 22                                                None
# 23                                                None
# 24                                                None
# 25                                                None
# 26   @rosadiezglez Me he vuelto malo, ahora porque ...
# 27   📢Aviso 🔶NARANJA por #FMA #Nevadas ❄️🌨️❄️ en #C...
# 28                                                None
# 29   Información inútil sobre mi:\n\nAltura: 1,57\n...
# ..                                                 ...
# 84   ➡️➡️📷 Maravillosos los platos de cuchara en @a...
# 85                                                None
# 86   ⚠️AVISOS ROJOS⚠️ naranja y amarillo para toda ...
# 87                                                None
# 88   @FAquae Melón de agua \nSandía\nTú tía \nSu ma...
# 89                                                None
# 90   Información súper importante sobre mí:\n\nAltu...
# 91                                                None
# 92                                                None
# 93                                                None
# 94                                                None
# 95                                                None
# 96                                                None
# 97                                                None
# 98   MANGO #intimatedinner Paseo de Gracia, 36 - Ba...
# 99                                                None
# 100  @VanesaFeGa Mientras Twitter no escriba las le...
# 101                                               None
# 102                                               None
# 103  Comprobado: lo tradicional y sencillo es mucha...
# 104                                               None
# 105                                               None
# 106                                               None
# 107                                               None
# 108  ADOPTADA LLUVIA...nuestra princesa de ocho añi...
# 109  @pburelli @Reportero24 Ese pollo pronto será c...
# 110                                               None
# 111  “La poesía,en fin, esa energía secreta de la v...
# 112  Lo dice alguien que su contribución a la socie...
# 113                                               None
#
#                                              text2Proc  \
# 0    La veleta naranja se rompió de la tanto giro.\...
# 1    Toma Geroma! Pastillas de goma! Dabuten tronco...
# 2    @nancyacostatfe @Hibai_ @MabelFigueruelo De fr...
# 3    Parece que mermelada se cree el único ser cult...
# 4    Edamame en bartomate \n.\n.\n.\n#edamame #bart...
# 5    información inutil sobre mi:\n\naltura: 1'73\n...
# 6    Hoy está el día para un buen plato de lentejas...
# 7    Este sabroso crumble de calabaza y avellanas e...
# 8    informacion super inutil de mi:\n\naltura: 1,5...
# 9    ¡¡Que hambre!! ¿Y tú  que comes hoy?? Yo unas ...
# 10   Ahora sí se perdió el norte. Sodoma y gomorra ...
# 11   @yatedigoyoque @KIud0 Puedes recurrir al catal...
# 12   [💥PANCAKES CINNAMON ROLL💥 ]\n.\n.\n⬇️INGREDIEN...
# 13   @EstefaniaJoaq Yo no lo creo, más bien "esto e...
# 14   ⠀⠀⠀⠀⠀⠀⠀⠀⠀\n🇪🇸 Comenzamos las comidas de la Aso...
# 15   @yxngmozo @holiest_jambo el d rooibos y frambu...
# 16   @la_flawerova Yo hoy he comido judías verdes, ...
# 17   [💥PANCAKES CACAO💥 ]\n.\n.\n⬇️INGREDIENTES⬇️\n➖...
# 18   Peludito de 2 escasos años q está perdiendo vi...
# 19   en la aso d bcn a la q iba tooooooooooodoooooo...
# 20   @GaliciaED_ @RubenRguezVquez Esto es la pera. ...
# 21   El setter necesitado de adopción está en la ve...
# 22   Retrasar el parto para que el médico vuelva de...
# 23   Está en una veterinaria de Ópera, de la médico...
# 24                      "Este sí es un refrán gallego"
# 25   estamos de acuerdo en que la kas de naranja le...
# 26   @rosadiezglez Me he vuelto malo, ahora porque ...
# 27   📢Aviso 🔶NARANJA por #FMA #Nevadas ❄️🌨️❄️ en #C...
# 28   @FtimaCantalapi1 Me encanta el jugo de frutas,...
# 29   Información inútil sobre mi:\n\nAltura: 1,57\n...
# ..                                                 ...
# 84   ➡️➡️📷 Maravillosos los platos de cuchara en @a...
# 85   @rosadiezglez Tienes alzheimer. Tomate la medi...
# 86   ⚠️AVISOS ROJOS⚠️ naranja y amarillo para toda ...
# 87   informacion super inútil de mí:\n\naltura: 1'7...
# 88   @FAquae Melón de agua \nSandía\nTú tía \nSu ma...
# 89   'A José María hoy le han regalado\nUn coche pe...
# 90   Información súper importante sobre mí:\n\nAltu...
# 91   @oierazkarraga @clacunza La ha votado un señor...
# 92                       @jroto_ Comerte unas lentejas
# 93               La gente a la q le gusta el aquarius?
# 94                       fruta https://t.co/RPPLyt2mSP
# 95                        @chupacaca69 SOLO DIJE FRUTA
# 96   @TitotatinTT Pimiento rojo y pimiento verde\nT...
# 97   A continuación, dando por hecho que esa fruta ...
# 98   MANGO #intimatedinner Paseo de Gracia, 36 - Ba...
# 99   @Pol588 @NebraskaGuy212 Te gusta el pimiento? ...
# 100  @VanesaFeGa Mientras Twitter no escriba las le...
# 101  @TitotatinTT Échale un poquito de nada que es ...
# 102  Jamoncitos de pollo con tomate, la receta que ...
# 103  Comprobado: lo tradicional y sencillo es mucha...
# 104  @jrlaguardia Si me las quito yo veo una berenj...
# 105  @PuriRV Datos tontos sobre mí:\n\nAltura: 1'60...
# 106  información inutil sobre mi:\n\naltura: 1'59\n...
# 107                             el mango por la sartén
# 108  ADOPTADA LLUVIA...nuestra princesa de ocho añi...
# 109  @pburelli @Reportero24 Ese pollo pronto será c...
# 110  Exijo arco iris con luces en todos los conciertos
# 111  “La poesía,en fin, esa energía secreta de la v...
# 112  Lo dice alguien que su contribución a la socie...
# 113  información inutil sobre mi:\n\naltura: 1'74\n...
#
#                      user_location Country                            City  \
# 0                              NaN   Spain                       Palomeque
# 1                         València   Spain                        Valencia
# 2                              NaN   Spain                          Oviedo
# 3                  Gerona Cataluña   Spain                   Lloret de Mar
# 4                           Madrid   Spain                          Madrid
# 5                   La Línea Cádiz   Spain                         Sevilla
# 6       Las Palmas de Gran Canaria   Spain      Las Palmas de Gran Canaria
# 7                Ángel 40 Albacete   Spain                        Albacete
# 8                    Euskal Herria   Spain                         Zarautz
# 9                           Madrid   Spain                          Madrid
# 10                             NaN   Spain                        Calafell
# 11                             NaN   Spain              Mollet de Peralada
# 12              Barcelona Cataluña   Spain                        Zaragoza
# 13                             NaN   Spain            Jerez de la Frontera
# 14                             NaN   Spain                        Albacete
# 15            Castelldefels España   Spain                         Granada
# 16                             NaN   Spain                          Madrid
# 17              Barcelona Cataluña   Spain                        Zaragoza
# 18                   Madrid España   Spain                          Madrid
# 19            Castelldefels España   Spain                         Granada
# 20                       Barcelona   Spain                       Barcelona
# 21                   Madrid España   Spain                          Madrid
# 22                         Macondo   Spain                          Madrid
# 23                   Madrid España   Spain                          Madrid
# 24               Miña terra galega   Spain                      Pontevedra
# 25        Málaga-Al-Ándalus-World.   Spain                          Málaga
# 26                             NaN   Spain                      Valladolid
# 27   Cabezón de la Sal (CANTABRIA)   Spain               Cabezón de la Sal
# 28       Madrid. Roma. Casablanca.   Spain                          Madrid
# 29            Barcelona - Mallorca   Spain                       Barcelona
# ..                             ...     ...                             ...
# 84                          Madrid   Spain                       Fuenmayor
# 85                             NaN   Spain            Vilanova i la Geltrú
# 86                Benavente España   Spain  Santa Cristina de la Polvorosa
# 87                   Málaga España   Spain                          Málaga
# 88                             NaN   Spain                         Sevilla
# 89             Barcelona Catalonia   Spain                       Barcelona
# 90                  Pedrola España   Spain                        Zaragoza
# 91                              EH   Spain                        Pamplona
# 92                             NaN   Spain                        Piélagos
# 93                             NaN   Spain                        Piélagos
# 94                             NaN   Spain                            Vigo
# 95                             NaN   Spain                            Vigo
# 96            Carmeningrado España   Spain                            Vigo
# 97                        Mallorca   Spain                           Palma
# 98                Barcelona España   Spain                       Barcelona
# 99      Madrid Comunidad de Madrid   Spain                          Madrid
# 100               Mollet Barcelona   Spain               Mollet del Vallès
# 101           Carmeningrado España   Spain                            Vigo
# 102                         Madrid   Spain                Sevilla la Nueva
# 103                  Getafe Madrid   Spain                          Madrid
# 104        Sentadito en mi tejado.   Spain                           Galar
# 105  Les Franqueses del Vallès Esp   Spain                   Pineda de Mar
# 106                            NaN   Spain              Boadilla del Monte
# 107                            NaN   Spain      Las Palmas de Gran Canaria
# 108                 Málaga (Spain)   Spain                          Málaga
# 109                 Ourense España   Spain                         Ourense
# 110                            NaN   Spain                        Valencia
# 111                         Madrid   Spain                          Madrid
# 112                            NaN   Spain                        Zaragoza
# 113    Jerez de la Frontera España   Spain                         Sevilla
#
#      Longitude   Latitude                        Coordinates
# 0    -4.017543  40.095033             (-4.017543, 40.095033)
# 1    -0.432545  39.278381  (-0.43254499999999996, 39.278381)
# 2    -6.020100  43.278867               (-6.0201, 43.278867)
# 3     2.775933  41.686311              (2.775933, 41.686311)
# 4    -3.889005  40.312071             (-3.889005, 40.312071)
# 5    -6.028430  37.313613              (-6.02843, 37.313613)
# 6   -15.525504  28.024813            (-15.525504, 28.024813)
# 7    -2.181299  38.672083             (-2.181299, 38.672083)
# 8    -2.209988  43.242870              (-2.209988, 43.24287)
# 9    -3.889005  40.312071             (-3.889005, 40.312071)
# 10    1.557382  41.185780               (1.557382, 41.18578)
# 11    2.989088  42.326848    (2.9890879999999997, 42.326848)
# 12   -1.174093  41.451835             (-1.174093, 41.451835)
# 13   -6.306111  36.516968             (-6.306111, 36.516968)
# 14   -2.181299  38.672083             (-2.181299, 38.672083)
# 15   -3.699796  37.135903             (-3.699796, 37.135903)
# 16   -3.889005  40.312071             (-3.889005, 40.312071)
# 17   -1.174093  41.451835             (-1.174093, 41.451835)
# 18   -3.889005  40.312071             (-3.889005, 40.312071)
# 19   -3.699796  37.135903             (-3.699796, 37.135903)
# 20    2.052477  41.317048              (2.052477, 41.317048)
# 21   -3.889005  40.312071             (-3.889005, 40.312071)
# 22   -3.889005  40.312071             (-3.889005, 40.312071)
# 23   -4.579175  39.884537             (-4.579175, 39.884537)
# 24   -8.698411  42.343095             (-8.698411, 42.343095)
# 25   -4.587928  36.635585             (-4.587928, 36.635585)
# 26   -4.928146  41.523108             (-4.928146, 41.523108)
# 27   -4.276687  43.274255             (-4.276687, 43.274255)
# 28   -3.889005  40.312071             (-3.889005, 40.312071)
# 29    2.052477  41.317048              (2.052477, 41.317048)
# ..         ...        ...                                ...
# 84   -2.626081  42.441602             (-2.626081, 42.441602)
# 85    1.669598  41.201848              (1.669598, 41.201848)
# 86   -5.788541  41.938450              (-5.788541, 41.93845)
# 87   -4.587928  36.635585             (-4.587928, 36.635585)
# 88   -6.028430  37.313613              (-6.02843, 37.313613)
# 89    2.052477  41.317048              (2.052477, 41.317048)
# 90   -1.174093  41.451835             (-1.174093, 41.451835)
# 91   -1.694620  42.789017              (-1.69462, 42.789017)
# 92   -4.013130  43.330029              (-4.01313, 43.330029)
# 93   -4.013130  43.330029              (-4.01313, 43.330029)
# 94   -8.916355  42.129380              (-8.916355, 42.12938)
# 95   -8.916355  42.129380              (-8.916355, 42.12938)
# 96   -8.916355  42.129380              (-8.916355, 42.12938)
# 97    2.563782  39.125070               (2.563782, 39.12507)
# 98    2.052477  41.317048              (2.052477, 41.317048)
# 99   -3.889005  40.312071             (-3.889005, 40.312071)
# 100   2.188040  41.524029               (2.18804, 41.524029)
# 101  -8.916355  42.129380              (-8.916355, 42.12938)
# 102  -4.076755  40.332290              (-4.076755, 40.33229)
# 103  -3.889005  40.312071             (-3.889005, 40.312071)
# 104  -1.724087  42.697814             (-1.724087, 42.697814)
# 105   2.627270  41.615030                (2.62727, 41.61503)
# 106  -3.952603  40.377576             (-3.952603, 40.377576)
# 107 -15.525504  28.024813            (-15.525504, 28.024813)
# 108  -4.587928  36.635585             (-4.587928, 36.635585)
# 109  -8.003734  42.288179             (-8.003734, 42.288179)
# 110  -0.432545  39.278381  (-0.43254499999999996, 39.278381)
# 111  -3.889005  40.312071             (-3.889005, 40.312071)
# 112  -1.174093  41.451835             (-1.174093, 41.451835)
# 113  -6.028430  37.313613              (-6.02843, 37.313613)
#
# [114 rows x 22 columns]

# %%
# Tweets with extended entities (multimedia) from Spain
df_spain[df_spain['extended_entities'].notna()]
# Out:
#      level_0  index coordinates               created_at  geo  \
# 18      1837   5733         NaN  2019-11-13 14:29:31.000  NaN
# 31      3205  10096         NaN  2019-11-13 15:07:43.000  NaN
# 38      4049  12747         NaN  2019-11-13 15:30:20.000  NaN
# 94     12979  38959         NaN  2019-11-13 18:54:13.000  NaN
# 99     13169  39501         NaN  2019-11-13 18:58:32.000  NaN
# 102    13837  41343         NaN  2019-11-13 19:14:46.000  NaN
#
#                       id               id_str lang  \
# 18   1194623329220595712  1194623329220595712   es
# 31   1194632943685095424  1194632943685095424   es
# 38   1194638635213025282  1194638635213025280   es
# 94   1194689942691209217  1194689942691209216   es
# 99   1194691029565419520  1194691029565419520   es
# 102  1194695117359087616  1194695117359087616   es
#
#                                                  place  \
# 18   {'id': '206c436ce43a43a3', 'url': 'https://api...
# 31   {'id': '342f9faf7392d4ce', 'url': 'https://api...
# 38   {'id': 'a4d75ab3c00c2563', 'url': 'https://api...
# 94   {'id': '0df6ac4d361d4e0e', 'url': 'https://api...
# 99   {'id': '206c436ce43a43a3', 'url': 'https://api...
# 102  {'id': '71d49086a15d032e', 'url': 'https://api...
#
#                                                   text  \
# 18   Peludito de 2 escasos años q está perdiendo vi...
# 31   Las lentejas y la adjika casera (más verde que...
# 38   Celebremos el Día Mundial de la Dieta Mediterr...
# 94                       fruta https://t.co/RPPLyt2mSP
# 99   @Pol588 @NebraskaGuy212 Te gusta el pimiento? ...
# 102  Jamoncitos de pollo con tomate, la receta que ...
#
#               ...           truncated  \
# 18            ...               False
# 31            ...               False
# 38            ...               False
# 94            ...               False
# 99            ...               False
# 102           ...               False
#
#                                      extended_entities  full_text  \
# 18   {'media': [{'id': 1194623305468104704, 'id_str...       None
# 31   {'media': [{'id': 1194632930758279169, 'id_str...       None
# 38   {'media': [{'id': 1194638616439480320, 'id_str...       None
# 94   {'media': [{'id': 1194689936139718661, 'id_str...       None
# 99   {'media': [{'id': 1194691021571002374, 'id_str...       None
# 102  {'media': [{'id': 1194695111118077952, 'id_str...       None
#
#                                              text2Proc  \
# 18   Peludito de 2 escasos años q está perdiendo vi...
# 31   Las lentejas y la adjika casera (más verde que...
# 38   Celebremos el Día Mundial de la Dieta Mediterr...
# 94                       fruta https://t.co/RPPLyt2mSP
# 99   @Pol588 @NebraskaGuy212 Te gusta el pimiento? ...
# 102  Jamoncitos de pollo con tomate, la receta que ...
#
#                   user_location Country              City Longitude  \
# 18                Madrid España   Spain            Madrid -3.889005
# 31                 🇪🇸 | 🇺🇦 | 🇷🇺   Spain           Logroño -2.542232
# 38              Níjar (Almería)   Spain             Níjar -2.300484
# 94                          NaN   Spain              Vigo -8.916355
# 99   Madrid Comunidad de Madrid   Spain            Madrid -3.889005
# 102                      Madrid   Spain  Sevilla la Nueva -4.076755
#
#       Latitude             Coordinates
# 18   40.312071  (-3.889005, 40.312071)
# 31   42.429049  (-2.542232, 42.429049)
# 38   36.719095  (-2.300484, 36.719095)
# 94   42.129380   (-8.916355, 42.12938)
# 99   40.312071  (-3.889005, 40.312071)
# 102  40.332290   (-4.076755, 40.33229)
#
# [6 rows x 22 columns]
