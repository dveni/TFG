# %%
from imageai.Detection import ObjectDetection
# Out:
# Using TensorFlow backend.
# /home/dvera/anaconda3/envs/TFG/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/dvera/anaconda3/envs/TFG/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/dvera/anaconda3/envs/TFG/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import os
import glob

execution_path = os.getcwd()

images = glob.glob('../data/images/**/*.jpg')
images.sort()


detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath(os.path.join(execution_path, "resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()

detections_list = []
i = 0
for image in images:
    print(i)
    print(image)
    detections = detector.detectObjectsFromImage(input_image=os.path.join(execution_path , image), output_image_path=os.path.join(execution_path , "ProcessedImages/image{}.jpg".format(i)), minimum_percentage_probability=30)
    i+=1
    detections_list.append(detections)
    for eachObject in detections:
        print(eachObject["name"] , " : ", eachObject["percentage_probability"], " : ", eachObject["box_points"] )
        print("--------------------------------")
# Out:
# WARNING:tensorflow:From /home/dvera/anaconda3/envs/TFG/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/dvera/anaconda3/envs/TFG/lib/python3.7/site-packages/imageai/Detection/keras_retinanet/backend/tensorflow_backend.py:22: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# tracking <tf.Variable 'Variable:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_1:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_2:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_3:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_4:0' shape=(9, 4) dtype=float32> anchors
# ...

# %%
tweet_ids = []
for image in images:
    tweet_ids.append(image.split('/')[1])

# %%
import pandas as pd
d = {'tweet_id': tweet_ids, 'detections':detections_list}
df = pd.DataFrame(data=d)
df.to_csv('../data/CSVFiles/detectionsDataFrame.csv', index=False)

# %%
df
# Out:
#                    tweet_id                                         detections
# 0    1.1924779342899323e+18  [{'name': 'cell phone', 'percentage_probabilit...
# 1     1.192479011081007e+18  [{'name': 'person', 'percentage_probability': ...
# 2     1.192507119435694e+18  [{'name': 'parking meter', 'percentage_probabi...
# 3    1.1925090602618266e+18  [{'name': 'person', 'percentage_probability': ...
# 4    1.1925241126290596e+18  [{'name': 'dining table', 'percentage_probabil...
# ..                      ...                                                ...
# 423   1.206192457249112e+18  [{'name': 'bicycle', 'percentage_probability':...
# 424   1.206192457249112e+18  [{'name': 'bicycle', 'percentage_probability':...
# 425   1.206192457249112e+18  [{'name': 'bicycle', 'percentage_probability':...
# 426   1.206236831173501e+18  [{'name': 'suitcase', 'percentage_probability'...
# 427  1.2062681807312364e+18  [{'name': 'person', 'percentage_probability': ...
#
# [428 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 2 columns):
# tweet_id      428 non-null object
# detections    428 non-null object
# dtypes: object(2)
# memory usage: 6.8+ KB

# %%
df['tweet_id_int'] = df.tweet_id.astype(float)
df.tweet_id_int[0]
# Out:
# 1.1924779342899323e+18

# %%
len(df.tweet_id.unique())
# Out:
# 335

# %%
df.detections[34
             ]
# Out:
# [{'name': 'person',
#   'percentage_probability': 32.81621336936951,
#   'box_points': [621, 2, 761, 133]},
#  {'name': 'bottle',
#   'percentage_probability': 46.539315581321716,
#   'box_points': [112, -5, 635, 968]},
#  {'name': 'cup',
#   'percentage_probability': 68.10199618339539,
#   'box_points': [97, 16, 629, 982]}]

# %%
df_spain = pd.read_csv('../data/CSVFiles/SpainUnhealthyFoodDataframe.csv')

# %%
df_spain
# Out:
#       level_0    index                                        coordinates  \
# 0          55      156                                                NaN
# 1         757     2185                                                NaN
# 2         829     2396                                                NaN
# 3         837     2413                                                NaN
# 4         995     2903                                                NaN
# ...       ...      ...                                                ...
# 8426  1339566  3155847                                                NaN
# 8427  1340445  3158132                                                NaN
# 8428  1340590  3158471                                                NaN
# 8429  1341063  3159649  {'type': 'Point', 'coordinates': [-0.988300000...
# 8430  1341073  3159663                                                NaN
#
#                    created_at  \
# 0     2019-11-07 15:52:03.000
# ...

# %%
df_spain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8431 entries, 0 to 8430
# Data columns (total 21 columns):
# level_0              8431 non-null int64
# index                8431 non-null int64
# coordinates          1231 non-null object
# created_at           8431 non-null object
# geo                  1231 non-null object
# id                   8431 non-null float64
# id_str               8431 non-null float64
# lang                 8431 non-null object
# place                8431 non-null object
# text                 8431 non-null object
# user                 8431 non-null object
# extended_tweet       3153 non-null object
# truncated            8431 non-null float64
# extended_entities    510 non-null object
# full_text            2687 non-null object
# user_location        7414 non-null object
# Country              8431 non-null object
# City                 8431 non-null object
# Longitude            8431 non-null float64
# Latitude             8431 non-null float64
# ...

# %%
a = df_spain.id[df_spain.id  == df.tweet_id_int[3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a0db809eefde> in <module>()
# ----> 1 a = df_spain.id[df_spain.id  == df.tweet_id_int[3]]
#
# NameError: name 'df_spain' is not defined
